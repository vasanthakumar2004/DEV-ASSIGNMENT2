# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("winequalityN.csv")

# %%
df1=df.head(50)

# %%
df1
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
# ...

# %%
df1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      49.000000         50.000000    50.000000       49.000000
# mean        7.059184          0.295800     0.344200        5.412245
# std         0.692194          0.119814     0.099552        5.705311
# min         5.800000          0.120000     0.040000        1.000000
# 25%         6.600000          0.232500     0.312500        1.400000
# 50%         7.000000          0.270000     0.360000        2.500000
# 75%         7.400000          0.310000     0.400000        7.400000
# max         8.600000          0.670000     0.620000       20.700000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  50.000000            50.000000              50.00000  50.000000
# mean    0.054340            32.960000             138.76000   0.994132
# std     0.026905            14.085685              38.49599   0.002805
# ...

# %%
df1.nunique()
# Out:
# type                     1
# fixed acidity           19
# volatile acidity        25
# citric acid             22
# residual sugar          29
# chlorides               27
# free sulfur dioxide     28
# total sulfur dioxide    39
# density                 29
# pH                      29
# sulphates               23
# alcohol                 25
# quality                  5
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# type                    0
# fixed acidity           1
# volatile acidity        0
# citric acid             0
# residual sugar          1
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df1.dropna(inplace=True)
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# ...

# %%
plt.bar(df1['quality'],df1['alcohol'])
plt.xlabel('WINE QUALITY')
plt.ylabel('ALCOHOL LEVEL')
# Out:
# Text(0, 0.5, 'ALCOHOL LEVEL')

# %%
plt.hist(df1['residual sugar'],color='green',edgecolor='black')
plt.title('Residual sugar')
# Out:
# Text(0.5, 1.0, 'Residual sugar')

# %%
df1.plot.bar()

# %%
plt.boxplot(df1['total sulfur dioxide'])
plt.title('SULFURDIOXIDE LEVEL')
# Out:
# Text(0.5, 1.0, 'SULFURDIOXIDE LEVEL')

# %%
plt.scatter(df1['residual sugar'],df1['alcohol'],color='yellow')
plt.xlabel('RESIDUAL SUGAR')
plt.ylabel('ALCOHOL LEVEL')
# Out:
# Text(0, 0.5, 'ALCOHOL LEVEL')

# %%
plt.plot(df1['alcohol'],label='alcohol')
plt.title('ALCOHOL LEVEL')
# Out:
# Text(0.5, 1.0, 'ALCOHOL LEVEL')

# %%
plt.stem(df1['pH'])
plt.title("pH LEVEL")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'pH LEVEL')

# %%
df.plot.area()
